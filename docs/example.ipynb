# %% [markdown]
# # stactools-global-mangrove-watch
#
# This is a small notebook demonstrating use of this package and its generated items and collections.
# It is intended to be executed from the root of this repository, since it relies on files that have been checked into this repo.

# %% [markdown]
# ## Example items and collections
#
# This package provides some example data, in the `examples/` directory.
# You can load them with [pystac](https://github.com/stac-utils/pystac).
# The item includes a custom attribute that is specific to this package.

# %%
from pathlib import Path

from IPython.display import display
from pystac import Collection

import stactools.global_mangrove_watch.stac

root = Path().cwd().parent
collection = Collection.from_file(str(root / "examples" / "collection.json"))
display(collection)
item = next(collection.get_items())
display(item)
# Out:
# <Collection id=global-mangrove-watch-3.0>
# <Item id=GMW_N26W082_2020_v3>

# %% [markdown]
# ## Creating items and collections
#
# Items can be created from an href to an annual mangrove extent layer, and optionally an href to the accompanying change layer (1996-`{year}`).
# Items are added to collections using the standard pystac interface.

# %%
cog_asset_href = root / "tests" / "data" / "GMW_N26W082_2020_v3.tif"
change_asset_href = root / "tests" / "data" / "GMW_N26W082_chng_f1996_t2020_v3.tif"
item = stactools.global_mangrove_watch.stac.create_item(
    cog_asset_href=str(cog_asset_href), change_asset_href=str(change_asset_href)
)
collection = stactools.global_mangrove_watch.stac.create_collection()
collection.add_item(item)
display(collection)
# Out:
# <Collection id=global-mangrove-watch-3.0>
